# %% [markdown]
# <a href="https://colab.research.google.com/github/kairamilanifitria/Green-Digital-Skills/blob/main/Result_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data for CO2 Emission and File Size Reduction
categories = ['Long Code', 'Short Code']
co2_emissions = [1.943, 1.593]  # CO2 emissions in grams
file_sizes = [6.11, 5.01]  # File sizes in MB

# Data for Code Processing Speed
libraries = ['Matplotlib', 'Plotly', 'Bokeh']
long_processing_speed = [0.490, 0.341, 0.428]  # Processing speed in seconds for long code
short_processing_speed = [0.260, 0.093, 0.087]  # Processing speed in seconds for short code

# Data for Memory and CPU Utilization
memory_usage = {
    'Matplotlib': {'Long Code': 110788, 'Short Code': 110748},
    'Plotly': {'Long Code': 111136, 'Short Code': 110544},
    'Bokeh': {'Long Code': 167908, 'Short Code': 167908}
}

cpu_time = {
    'Matplotlib': {'Long Code': 2.485927, 'Short Code': 2.258821},
    'Plotly': {'Long Code': 2.094543, 'Short Code': 3.473306},
    'Bokeh': {'Long Code': 4.320924, 'Short Code': 4.590133}
}

# Data for Web Page Performance
performance_scores = ['FCP', 'SI', 'LCP', 'TBT']
long_performance_times = [3410, 5948, 5533, 708]  # Performance times in milliseconds for long code
short_performance_times = [2704, 6209, 5067, 647]  # Performance times in milliseconds for short code

# %% [markdown]
# CO2 Emission and File Size Reduction:

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# Data for CO2 Emission and File Size Reduction
categories = ['Long Code', 'Short Code']
co2_emissions = [1.943, 1.593]  # CO2 emissions in grams
file_sizes = [6.11, 5.01]  # File sizes in MB

# Graph 1: CO2 Emission and File Size Reduction
plt.figure(figsize=(10, 6))

# Plotting CO2 emissions
plt.subplot(1, 2, 1)
plt.bar(categories, co2_emissions, color=['lavender', 'plum'])
plt.title('CO2 Emission (g)')
plt.ylabel('CO2 Emission (g)')

# Adding numbers above the bars
for i, emission in enumerate(co2_emissions):
    plt.text(i, emission + 0.05, str(emission), ha='center', va='center_baseline')

# Plotting file sizes
plt.subplot(1, 2, 2)
plt.bar(categories, file_sizes, color=['lavender', 'plum'])
plt.title('File Size (MB)')
plt.ylabel('File Size (MB)')

# Adding numbers above the bars
for i, size in enumerate(file_sizes):
    plt.text(i, size + 0.05, str(size), ha='center', va='bottom')

plt.show()

# %% [markdown]
# Code Processing Speed:

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# Data for Code Processing Speed
libraries = ['Matplotlib', 'Plotly', 'Bokeh']
long_processing_speed = [0.490, 0.341, 0.428]  # Processing speed in seconds for long code
short_processing_speed = [0.260, 0.093, 0.087]  # Processing speed in seconds for short code

# Adjust the x positions for short code bars
x_long = np.arange(len(libraries))
x_short = x_long + 0.35  # Move the short code bars to the right of the long code bars

# Graph: Code Processing Speed
plt.figure(figsize=(8, 5))

# Plotting long code processing speed
plt.bar(x_long, long_processing_speed, label='Long Code', color='lavender', width=0.35)

# Plotting short code processing speed
plt.bar(x_short, short_processing_speed, label='Short Code', color='plum', width=0.35, alpha=0.6)

# Adding numbers above the bars
for i, speed in enumerate(long_processing_speed):
    plt.text(x_long[i], speed + 0.005, f'{speed:.3f}', ha='center', va='bottom')

for i, speed in enumerate(short_processing_speed):
    plt.text(x_short[i], speed + 0.005, f'{speed:.3f}', ha='center', va='bottom')

plt.xlabel('Library')
plt.ylabel('Processing Speed (s)')
plt.title('Code Processing Speed (seconds)')
plt.xticks(x_long + 0.17, libraries)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Memory and CPU Utilization:

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# Data for Memory and CPU Utilization
libraries = ['Matplotlib', 'Plotly', 'Bokeh']
code_lengths = ['Long Code', 'Short Code']

memory_usage = {
    'Matplotlib': [110788, 110748],
    'Plotly': [111136, 110544],
    'Bokeh': [167908, 167908]
}

# Calculate average memory usage for long and short code
avg_memory_long = sum(memory_usage[library][0] for library in libraries) / len(libraries)
avg_memory_short = sum(memory_usage[library][1] for library in libraries) / len(libraries)

# Detailed memory usage for each library
long_memory_detailed = [memory_usage[library][0] for library in libraries]
short_memory_detailed = [memory_usage[library][1] for library in libraries]

# Graph: Memory Usage Comparison (Line Chart)
plt.figure(figsize=(10, 6))

# Plotting the detailed memory usage for each library
plt.plot(libraries, long_memory_detailed, marker='o', label='Long Code', color='yellow')
plt.plot(libraries, short_memory_detailed, marker='o', label='Short Code', color='cyan')

# Add average memory usage lines
plt.axhline(y=avg_memory_long, linestyle='--', color='yellow', label=f'Avg Long Code: {avg_memory_long:.0f}')
plt.axhline(y=avg_memory_short, linestyle='--', color='cyan', label=f'Avg Short Code: {avg_memory_short:.0f}')

# Add labels and title
plt.xlabel('Library')
plt.ylabel('Memory Usage')
plt.title('Memory Usage Comparison')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# Data for Memory and CPU Utilization
libraries = ['Matplotlib', 'Plotly', 'Bokeh']
code_lengths = ['Long Code', 'Short Code']

cpu_time = {
    'Matplotlib': [2.485927, 2.258821],
    'Plotly': [2.094543, 3.473306],
    'Bokeh': [4.320924, 4.590133]
}

# Customized colors for bars
bar_colors = ['mediumpurple', 'plum', 'powderblue']  # Blue, orange, green

# Graph: CPU Time Comparison
plt.figure(figsize=(10, 6))

# Plotting CPU time for each library with custom colors
for i, library in enumerate(libraries):
    plt.bar([x + i * 0.2 for x in range(len(code_lengths))], cpu_time[library], width=0.2, label=library, color=bar_colors[i])

# Adding numbers above the bars
for i, library in enumerate(libraries):
    for j, time in enumerate(cpu_time[library]):
        plt.text(j + i * 0.2, time + 0.05, f'{time:.2f}', ha='center', va='bottom', color='white')

plt.xlabel('Code Length')
plt.ylabel('CPU Time')
plt.title('CPU Time Comparison')
plt.xticks([0.2, 1.2], code_lengths)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Web Page Performance:

# %% [markdown]
# Long Code:
# ![image.png](data:image/png;base64,...)
#
#
# Shorter code:
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# Data for Web Page Performance
performance_metrics = ['FCP', 'SI', 'LCP', 'TBT']
long_performance_times = [3410, 5948, 5533, 708]  # Performance scores and times for long code
short_performance_times = [2704, 6209, 5067, 647]  # Performance scores and times for short code

# Adjust the x positions for short code bars
x_long = np.arange(len(performance_metrics))
x_short = x_long + 0.35  # Move the short code bars to the right of the long code bars

# Graph: Web Page Performance
plt.figure(figsize=(10, 6))

# Plotting long code performance metrics
plt.bar(x_long, long_performance_times, label='Long Code', color='lavender', width=0.35)

# Plotting short code performance metrics
plt.bar(x_short, short_performance_times, label='Short Code', color='plum', width=0.35, alpha=0.6)

# Adding numbers above the bars for long code
for i, time in enumerate(long_performance_times):
    plt.text(x_long[i], time + 0.5, str(time), ha='center', va='bottom')

# Adding numbers above the bars for short code
for i, time in enumerate(short_performance_times):
    plt.text(x_short[i], time + 0.5, str(time), ha='center', va='bottom')

plt.xlabel('Performance Metrics')
plt.ylabel('Time (ms) / Score')
plt.title('Web Page Performance')
plt.xticks(x_long + 0.17, performance_metrics)
plt.legend()
plt.tight_layout()
plt.show()
